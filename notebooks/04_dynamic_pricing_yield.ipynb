# %% [markdown]
# # 🏰 Dynamic Pricing & Yield Management
#
# Constrained optimization and the annualized profit uplift.
#
# Production logic lives in `scripts/dynamic_pricing.py`.

# %%
# Run from repo root:  python scripts/dynamic_pricing.py
print('See scripts/dynamic_pricing.py for the optimizer.')
