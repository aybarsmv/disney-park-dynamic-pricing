# %% [markdown]
# # 🏰 Exploratory Data Analysis
#
# Seasonality, demand drivers, and distribution checks.

# %%
import pandas as pd
df = pd.read_csv('../data/disney_park_data.csv', parse_dates=['Date'])
df.describe()
