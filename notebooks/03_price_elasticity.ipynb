# %% [markdown]
# # 🏰 Price Elasticity of Demand
#
# Log-log demand estimation with controls.
#
# Production logic lives in `scripts/elasticity_model.py`.

# %%
import pandas as pd
from scripts.elasticity_model import estimate_elasticities
df = pd.read_csv('../data/disney_park_data.csv')
estimate_elasticities(df)
