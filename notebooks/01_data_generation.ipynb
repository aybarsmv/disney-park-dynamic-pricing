# %% [markdown]
# # 🏰 Data Generation
#
# Narrative walkthrough of the synthetic-data simulator.
#
# The production logic lives in `scripts/generate_dataset.py`.

# %%
from scripts.generate_dataset import build_dataset
df = build_dataset()
df.head()
